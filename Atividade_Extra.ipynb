# %% [markdown]
# # Atividade Extra
#
#   *   **Aluna**: Alice Soares Pereira de Barros

# %% [markdown]
# ### > Descrição
#
# Faça um estudo comparativo considerando *pelo menos 5 cursos de graduação (+BTI, +BCT) de cada centro* (https://www.ufrn.br/institucional/unidades-institucionais) e para os programas de pós graduação *PPgEEC, PPgSC, PPgSW, PPgITE, PPgBIOINF.*
#
# Compartilhe o notebook final no github (envie o link do repositório) escrevendo suas conclusões e comparando os resultados das áreas com os dados gerais da UFRN.
#
# **OBS.:** Trabalho pode ser feito em dupla e irá valer 3,00 (três) pontos extras na segunda avaliação.
#
#
# ### > Cursos de Graduação de cada Centro (+BTI, +BCT):
#
# **BTI** - Bacharelado em Tecnologia da Informação
#
# **BCT** - Bacharelado em Ciências e Tecnologia
#
# **CB** -  Engenharia de Aquicultura, Biomedicina, Ciências Biológicas, Ciências Biológicas à Distância e Ecologia;
#
# **CCS** -  Educação Física, Medicina, Enfermagem, Fonoaudiologia, Nutrição, Farmácia, Fisioterapia, Odontologia, Gestão Sist. Serv. em Saúde;
#
# **CCET** - Ciências Atuariais, Ciência da Computação, Engenharia de Software, Estatística, Física, Geofísica, Geologia, Matemática, Meteorologia, Química, Química do Petróleo;
#
# **CCHLA** - Artes Visuais, Ciências Sociais,	Comunicação Social,	Dança, Design, Educação Artística, Filosofia, Geografia, História, Letras, Gestão em Políticas Públicas, Psicologia, Teatro;
#
# **CCSA** - Administração, Ciência da Informação, Ciências Contábeis, Ciências Econômicas, Direito, Serviço Social, Turismo;
#
# **CE** - Pedagogia;
#
# **CERES** - Administração, Ciências Contábeis, Direito, Geografia (Bacharelado), Geografia (Licenciatura), História (Bacharelado), História (Licenciatura), Letras Espanhol, Letras Português, Pedagogia, Turismo;
#
# **CT** - Arquitetura e Urbanismo, Engenharia de Alimentos, Engenharia Biomédica, Engenharia Civil, Engenharia de Computação, Engenharia de Telecomunicações, Engenharia Elétrica, Engenharia de Materiais, Engenharia Mecânica, Engenharia de Petróleo, Engenharia de Produção, Engenharia Química, Engenharia Têxtil, Engenharia Ambiental, Engenharia Mecatrônica;
#
# ### > Cursos de Pós-Graduação:
#
# ***PPgEEC*** - Programa de Pós-graduação em Engenharia Elétrica e de Computação;
#
# ***PPgSC*** - Programa de Pós-graduação em Sistemas e Computação;
#
# ***PPgSW*** - Programa de Pós-graduação em Engenharia de Software;
#
# ***PPgITE*** -  Programa de Pós-graduação em Inovação em Tecnologias Educacionais;
#
# ***PPgBIOINF*** - Programa de Pós-graduação em Bioinformática.
#
#
# ### > Cursos escolhidos (+BTI, +BCT):
#
# Bacharelado em Tecnologia da Informação (BTI), Bacharelado em Ciências e Tecnologia (BCT), Biomedicina,  Design,  Direito,  Educação Física,  Engenharia de Produção, Pedagogia e Química.
#
#
# ### > Perguntas:
#
# **1 -** Como está a questão da diferença de gêneros nos cursos de graduação e pós-graduação da UFRN ao longo dos anos?
#
# **2 -** 2 - E em relação à etnia/raça?

# %% [markdown]
# ###  Base de Dados

# %%
# importando pandas
import pandas as pd

# pesquisa
discentes_UFRN = 'discentes_UFRN.xlsx'

# criando um dataframe de um arquivo excel
excel = pd.ExcelFile(discentes_UFRN)

# imprimindo os nomes das 'camadas'/planilhas
print(excel.sheet_names)

# Dataframes
d2009 = excel.parse(0)
d2010 = excel.parse(1)
d2011 = excel.parse(2)
d2012 = excel.parse(3)
d2013 = excel.parse(4)
d2014 = excel.parse(5)
d2015 = excel.parse(6)
d2016 = excel.parse(7)
d2017 = excel.parse(8)
d2018 = excel.parse(9)
d2019 = excel.parse(10)
# Out:
# ['discentes-2009', 'discentes-2010', 'discentes-2011', 'discentes-2012', 'discentes-2013', 'discentes-2014', 'discentes-2015', 'discentes-2016', 'discentes-2017', 'discentes-2018', 'discentes-2019']

# %% [markdown]
# ###  > QUESTÃO 1- (GRADUAÇÃO):

# %%
#1- (BTI):
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 7, figsize = (35, 5))

# como o curso de BTI iniciou em 2013, utilizaremos os dados a partir de 2013:
d2013[d2013.nome_curso == "TECNOLOGIA DA INFORMAÇÃO"].sexo.\
value_counts().plot.bar(title = 'Ingressantes no BTI em 2013',
                        ax=ax[0], ylim = (0,340))

d2014[d2014.nome_curso == "TECNOLOGIA DA INFORMAÇÃO"].sexo.\
value_counts().plot.bar(title = 'Ingressantes no BTI em 2014',
                        ax=ax[1], ylim = (0,340))

d2015[d2015.nome_curso == "TECNOLOGIA DA INFORMAÇÃO"].sexo.\
value_counts().plot.bar(title = 'Ingressantes no BTI em 2015',
                        ax=ax[2], ylim = (0,340))

d2016[d2016.nome_curso == "TECNOLOGIA DA INFORMAÇÃO"].sexo.\
value_counts().plot.bar(title = 'Ingressantes no BTI em 2016',
                        ax=ax[3], ylim = (0,340))

d2017[d2017.nome_curso == "TECNOLOGIA DA INFORMAÇÃO"].sexo.\
value_counts().plot.bar(title = 'Ingressantes no BTI em 2017',
                        ax=ax[4], ylim = (0,340))

d2018[d2018.nome_curso == "TECNOLOGIA DA INFORMAÇÃO"].sexo.\
value_counts().plot.bar(title = 'Ingressantes no BTI em 2018',
                        ax=ax[5], ylim = (0,340))

d2019[d2019.nome_curso == "TECNOLOGIA DA INFORMAÇÃO"].sexo.\
value_counts().plot.bar(title = 'Ingressantes no BTI em 2019',
                        ax=ax[6], ylim = (0,340))

# %% [markdown]
# No BTI, a quantidade de alunos ingressantes é, em sua maioria, formada por homens e há, ao longo do anos, um número aproximadamente constante de mulheres ingressantes.

# %%
# 1 - (BCT):
fig, ax = plt.subplots(1, 11, figsize = (50, 5))

d2009[d2009.nome_curso == "CIÊNCIAS E TECNOLOGIA"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em BCT em 2009', ax=ax[0], ylim = (0,1000))

d2010[d2010.nome_curso == "CIÊNCIAS E TECNOLOGIA"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em BCT em 2010', ax=ax[1], ylim = (0,1000))

d2011[d2011.nome_curso == "CIÊNCIAS E TECNOLOGIA"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em BCT em 2011', ax=ax[2], ylim = (0,1000))

d2012[d2012.nome_curso == "CIÊNCIAS E TECNOLOGIA"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em BCT em 2012', ax=ax[3], ylim = (0,1000))

d2013[d2013.nome_curso == "CIÊNCIAS E TECNOLOGIA"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em BCT em 2013', ax=ax[4], ylim = (0,1000))

d2014[d2014.nome_curso == "CIÊNCIAS E TECNOLOGIA"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em BCT em 2014', ax=ax[5], ylim = (0,1000))

d2015[d2015.nome_curso == "CIÊNCIAS E TECNOLOGIA"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em BCT em 2015', ax=ax[6], ylim = (0,1000))

d2016[d2016.nome_curso == "CIÊNCIAS E TECNOLOGIA"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em BCT em 2016', ax=ax[7], ylim = (0,1000))

d2017[d2017.nome_curso == "CIÊNCIAS E TECNOLOGIA"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em BCT em 2017', ax=ax[8], ylim = (0,1000))

d2018[d2018.nome_curso == "CIÊNCIAS E TECNOLOGIA"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em BCT em 2018', ax=ax[9], ylim = (0,1000))

d2019[d2019.nome_curso == "CIÊNCIAS E TECNOLOGIA"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em BCT em 2019', ax=ax[10], ylim = (0,1000))

# %% [markdown]
# No BCT, a quantidade de alunos ingressantes é, em sua maioria, formada por homens e há, desde 2010,  um número aproximadamente constante de mulheres ingressantes.

# %%
# 1 - (BIOMEDICINA):
fig, ax = plt.subplots(1, 11, figsize = (54, 5))

d2009[d2009.nome_curso == "BIOMEDICINA"].sexo.value_counts().plot.\
bar(title = 'Ingressantes em Biomedicina em 2009', ax=ax[0], ylim = (0,100))

d2010[d2010.nome_curso == "BIOMEDICINA"].sexo.value_counts().plot.\
bar(title = 'Ingressantes em Biomedicina em 2010', ax=ax[1], ylim = (0,100))

d2011[d2011.nome_curso == "BIOMEDICINA"].sexo.value_counts().plot.\
bar(title = 'Ingressantes em Biomedicina em 2011', ax=ax[2], ylim = (0,100))

d2012[d2012.nome_curso == "BIOMEDICINA"].sexo.value_counts().plot.\
bar(title = 'Ingressantes em Biomedicina em 2012', ax=ax[3], ylim = (0,100))

d2013[d2013.nome_curso == "BIOMEDICINA"].sexo.value_counts().plot.\
bar(title = 'Ingressantes em Biomedicina em 2013', ax=ax[4], ylim = (0,100))

d2014[d2014.nome_curso == "BIOMEDICINA"].sexo.value_counts().plot.\
bar(title = 'Ingressantes em Biomedicina em 2014', ax=ax[5], ylim = (0,100))

d2015[d2015.nome_curso == "BIOMEDICINA"].sexo.value_counts().plot.\
bar(title = 'Ingressantes em Biomedicina em 2015', ax=ax[6], ylim = (0,100))

d2016[d2016.nome_curso == "BIOMEDICINA"].sexo.value_counts().plot.\
bar(title = 'Ingressantes em Biomedicina em 2016', ax=ax[7], ylim = (0,100))

d2017[d2017.nome_curso == "BIOMEDICINA"].sexo.value_counts().plot.\
bar(title = 'Ingressantes em Biomedicina em 2017', ax=ax[8], ylim = (0,100))

d2018[d2018.nome_curso == "BIOMEDICINA"].sexo.value_counts().plot.\
bar(title = 'Ingressantes em Biomedicina em 2018', ax=ax[9], ylim = (0,100))

d2019[d2019.nome_curso == "BIOMEDICINA"].sexo.value_counts().plot.\
bar(title = 'Ingressantes em Biomedicina em 2019', ax=ax[10], ylim = (0,100))

# %% [markdown]
# No curso de Biomedicina, a quantidade de alunos ingressantes é,  em sua maioria, formada por mulheres. O número de homens ingressantes mantém-se constante.

# %%
# 1 - (DESIGN): 
fig, ax = plt.subplots(1, 11, figsize = (50, 5))

d2009[d2009.nome_curso == "DESIGN"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em Design em 2009', ax=ax[0], ylim = (0,40))

d2010[d2010.nome_curso == "DESIGN"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em Design em 2010', ax=ax[1], ylim = (0,40))

d2011[d2011.nome_curso == "DESIGN"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em Design em 2011', ax=ax[2], ylim = (0,40))

d2012[d2012.nome_curso == "DESIGN"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em Design em 2012', ax=ax[3], ylim = (0,40))

d2013[d2013.nome_curso == "DESIGN"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em Design em 2013', ax=ax[4], ylim = (0,40))

d2014[d2014.nome_curso == "DESIGN"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em Design em 2014', ax=ax[5], ylim = (0,40))

d2015[d2015.nome_curso == "DESIGN"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em Design em 2015', ax=ax[6], ylim = (0,40))

d2016[d2016.nome_curso == "DESIGN"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em Design em 2016', ax=ax[7], ylim = (0,40))

d2017[d2017.nome_curso == "DESIGN"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em Design em 2017', ax=ax[8], ylim = (0,40))

d2018[d2018.nome_curso == "DESIGN"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em Design em 2018', ax=ax[9], ylim = (0,40))

d2019[d2019.nome_curso == "DESIGN"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em Design em 2019', ax=ax[10], ylim = (0,40))

# %% [markdown]
# Em Design, a quantidade de alunos ingressantes é, em sua maioria, formada por mulheres e há, ao longo do anos, um número aproximadamente constante de homens ingressantes.

# %%
# 1 - (DIREITO): 
fig, ax = plt.subplots(1, 11, figsize = (50, 5))

d2009[d2009.nome_curso == "DIREITO"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em Direito em 2009', ax=ax[0], ylim = (0,200))

d2010[d2010.nome_curso == "DIREITO"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em Direito em 2010', ax=ax[1], ylim = (0,200))

d2011[d2011.nome_curso == "DIREITO"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em Direito em 2011', ax=ax[2], ylim = (0,200))

d2012[d2012.nome_curso == "DIREITO"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em Direito em 2012', ax=ax[3], ylim = (0,200))

d2013[d2013.nome_curso == "DIREITO"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em Direito em 2013', ax=ax[4], ylim = (0,200))

d2014[d2014.nome_curso == "DIREITO"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em Direito em 2014', ax=ax[5], ylim = (0,200))

d2015[d2015.nome_curso == "DIREITO"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em Direito em 2015', ax=ax[6], ylim = (0,200))

d2016[d2016.nome_curso == "DIREITO"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em Direito em 2016', ax=ax[7], ylim = (0,200))

d2017[d2017.nome_curso == "DIREITO"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em Direito em 2017', ax=ax[8], ylim = (0,200))

d2018[d2018.nome_curso == "DIREITO"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em Direito em 2018', ax=ax[9], ylim = (0,200))

d2019[d2019.nome_curso == "DIREITO"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em Direito em 2019', ax=ax[10], ylim = (0,200))

# %% [markdown]
# No curso de Direito, a quantidade de alunos ingressantes é mais equilibrada. De 2009 a 2012, houve um aumento na quantidade de mulheres ingressantes, sendo superado em 2012, porém, nos anos seguintes, foi diminuindo.

# %%
# 1 - (EDUCAÇÃO FÍSICA):
fig, ax = plt.subplots(1, 11, figsize = (50, 5))

d2009[d2009.nome_curso == "EDUCAÇÃO FÍSICA"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em Educação Física em 2009', ax=ax[0], ylim = (0,500))

d2010[d2010.nome_curso == "EDUCAÇÃO FÍSICA"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em Educação Física em 2010', ax=ax[1], ylim = (0,500))

d2011[d2011.nome_curso == "EDUCAÇÃO FÍSICA"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em Educação Física em 2011', ax=ax[2], ylim = (0,500))

d2012[d2012.nome_curso == "EDUCAÇÃO FÍSICA"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em Educação Física em 2012', ax=ax[3], ylim = (0,500))

d2013[d2013.nome_curso == "EDUCAÇÃO FÍSICA"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em Educação Física em 2013', ax=ax[4], ylim = (0,500))

d2014[d2014.nome_curso == "EDUCAÇÃO FÍSICA"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em Educação Física em 2014', ax=ax[5], ylim = (0,500))

d2015[d2015.nome_curso == "EDUCAÇÃO FÍSICA"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em Educação Física em 2015', ax=ax[6], ylim = (0,500))

d2016[d2016.nome_curso == "EDUCAÇÃO FÍSICA"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em Educação Física em 2016', ax=ax[7], ylim = (0,500))

d2017[d2017.nome_curso == "EDUCAÇÃO FÍSICA"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em Educação Física em 2017', ax=ax[8], ylim = (0,500))

d2018[d2018.nome_curso == "EDUCAÇÃO FÍSICA"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em Educação Física em 2018', ax=ax[9], ylim = (0,500))

d2019[d2019.nome_curso == "EDUCAÇÃO FÍSICA"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em Educação Física em 2019', ax=ax[10], ylim = (0,500))

plt.tight_layout()

# %% [markdown]
# Em Educação Física, a quantidade de alunos ingressantes é, em sua maioria, formada por homens e há, ao longo do anos, uma queda na quantidade de mulheres ingressantes e um aumento de homens ingressantes.

# %%
# 1 - (ENGENHARIA DE PRODUÇÃO): 
fig, ax = plt.subplots(1, 11, figsize = (65, 5))

d2009[d2009.nome_curso == "ENGENHARIA DE PRODUÇÃO"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em Engenharia de Produção em 2009', ax=ax[0], ylim = (0,100))

d2010[d2010.nome_curso == "ENGENHARIA DE PRODUÇÃO"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em Engenharia de Produção em 2010', ax=ax[1], ylim = (0,100))

d2011[d2011.nome_curso == "ENGENHARIA DE PRODUÇÃO"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em Engenharia de Produção em 2011', ax=ax[2], ylim = (0,100))

d2012[d2012.nome_curso == "ENGENHARIA DE PRODUÇÃO"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em Engenharia de Produção em 2012', ax=ax[3], ylim = (0,100))

d2013[d2013.nome_curso == "ENGENHARIA DE PRODUÇÃO"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em Engenharia de Produção em 2013', ax=ax[4], ylim = (0,100))

d2014[d2014.nome_curso == "ENGENHARIA DE PRODUÇÃO"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em Engenharia de Produção em 2014', ax=ax[5], ylim = (0,100))

d2015[d2015.nome_curso == "ENGENHARIA DE PRODUÇÃO"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em Engenharia de Produção em 2015', ax=ax[6], ylim = (0,100))

d2016[d2016.nome_curso == "ENGENHARIA DE PRODUÇÃO"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em Engenharia de Produção em 2016', ax=ax[7], ylim = (0,100))

d2017[d2017.nome_curso == "ENGENHARIA DE PRODUÇÃO"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em Engenharia de Produção em 2017', ax=ax[8], ylim = (0,100))

d2018[d2018.nome_curso == "ENGENHARIA DE PRODUÇÃO"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em Engenharia de Produção em 2018', ax=ax[9], ylim = (0,100))

d2019[d2019.nome_curso == "ENGENHARIA DE PRODUÇÃO"].sexo.value_counts().plot\
.bar(title = 'Ingressantes em Engenharia de Produção em 2019', ax=ax[10], ylim = (0,100))

# %% [markdown]
# Em Engenharia de Produção, a quantidade de alunos ingressantes é, em sua maioria, formada por homens e há, ao longo do anos, um número aproximadamente constante de mulheres ingressantes.

# %%
# 1 - (PEDAGOGIA): 
fig, ax = plt.subplots(1, 11, figsize = (54, 5))

d2009[d2009.nome_curso == "PEDAGOGIA"].sexo.value_counts().plot.\
bar(title = 'Ingressantes em Pedagogia em 2009', ax=ax[0], ylim = (0,700))

d2010[d2010.nome_curso == "PEDAGOGIA"].sexo.value_counts().plot.\
bar(title = 'Ingressantes em Pedagogia em 2010', ax=ax[1], ylim = (0,700))

d2011[d2011.nome_curso == "PEDAGOGIA"].sexo.value_counts().plot.\
bar(title = 'Ingressantes em Pedagogia em 2011', ax=ax[2], ylim = (0,700))

d2012[d2012.nome_curso == "PEDAGOGIA"].sexo.value_counts().plot.\
bar(title = 'Ingressantes em Pedagogia em 2012', ax=ax[3], ylim = (0,700))

d2013[d2013.nome_curso == "PEDAGOGIA"].sexo.value_counts().plot.\
bar(title = 'Ingressantes em Pedagogia em 2013', ax=ax[4], ylim = (0,700))

d2014[d2014.nome_curso == "PEDAGOGIA"].sexo.value_counts().plot.\
bar(title = 'Ingressantes em Pedagogia em 2014', ax=ax[5], ylim = (0,700))

d2015[d2015.nome_curso == "PEDAGOGIA"].sexo.value_counts().plot.\
bar(title = 'Ingressantes em Pedagogia em 2015', ax=ax[6], ylim = (0,700))

d2016[d2016.nome_curso == "PEDAGOGIA"].sexo.value_counts().plot.\
bar(title = 'Ingressantes em Pedagogia em 2016', ax=ax[7], ylim = (0,700))

d2017[d2017.nome_curso == "PEDAGOGIA"].sexo.value_counts().plot.\
bar(title = 'Ingressantes em Pedagogia em 2017', ax=ax[8], ylim = (0,700))

d2018[d2018.nome_curso == "PEDAGOGIA"].sexo.value_counts().plot.\
bar(title = 'Ingressantes em Pedagogia em 2018', ax=ax[9], ylim = (0,700))

d2019[d2019.nome_curso == "PEDAGOGIA"].sexo.value_counts().plot.\
bar(title = 'Ingressantes em Pedagogia em 2019', ax=ax[10], ylim = (0,700))

# %% [markdown]
# No curso de Pedagogia a quantidade de alunos ingressantes é, em sua maioria, formada por mulheres e há, ao longo dos anos, uma quantidade aproximadamente constante de homens ingressantes.

# %%
# 1 - (QUÍMICA): 
fig, ax = plt.subplots(1, 11, figsize = (50, 5))

d2009[d2009.nome_curso == "QUÍMICA"].sexo.value_counts().plot.\
bar(title = 'Ingressantes em Química em 2009', ax=ax[0], ylim = (0,300))

d2010[d2010.nome_curso == "QUÍMICA"].sexo.value_counts().plot.\
bar(title = 'Ingressantes em Química em 2010', ax=ax[1], ylim = (0,300))

d2011[d2011.nome_curso == "QUÍMICA"].sexo.value_counts().plot.\
bar(title = 'Ingressantes em Química em 2011', ax=ax[2], ylim = (0,300))

d2012[d2012.nome_curso == "QUÍMICA"].sexo.value_counts().plot.\
bar(title = 'Ingressantes em Química em 2012', ax=ax[3], ylim = (0,300))

d2013[d2013.nome_curso == "QUÍMICA"].sexo.value_counts().plot.\
bar(title = 'Ingressantes em Química em 2013', ax=ax[4], ylim = (0,300))

d2014[d2014.nome_curso == "QUÍMICA"].sexo.value_counts().plot.\
bar(title = 'Ingressantes em Química em 2014', ax=ax[5], ylim = (0,300))

d2015[d2015.nome_curso == "QUÍMICA"].sexo.value_counts().plot.\
bar(title = 'Ingressantes em Química em 2015', ax=ax[6], ylim = (0,300))

d2016[d2016.nome_curso == "QUÍMICA"].sexo.value_counts().plot.\
bar(title = 'Ingressantes em Química em 2016', ax=ax[7], ylim = (0,300))

d2017[d2017.nome_curso == "QUÍMICA"].sexo.value_counts().plot.\
bar(title = 'Ingressantes em Química em 2017', ax=ax[8], ylim = (0,300))

d2018[d2018.nome_curso == "QUÍMICA"].sexo.value_counts().plot.\
bar(title = 'Ingressantes em Química em 2018', ax=ax[9], ylim = (0,300))

d2019[d2019.nome_curso == "QUÍMICA"].sexo.value_counts().plot.\
bar(title = 'Ingressantes em Química em 2019', ax=ax[10], ylim = (0,300))

# %% [markdown]
# No curso de Química, a quantidade de alunos ingressantes é, em sua maioria, formada por homens e há, ao longo do anos, um número aproximadamente constante de mulheres ingressantes.

# %% [markdown]
# ### > RESPOSTA (GRADUAÇÃO):
#
# Analisando os gráficos dos cursos de Bacharelado em Tecnologia da Informação (BTI), Bacharelado em Ciências e Tecnologia (BCT), Biomedicina, Design, Direito, Educação Física, Engenharia de Produção, Pedagogia e Química, é perceptível que a questão da diferença de gêneros ao longo dos anos é relativa com os cursos, por exemplo, nos  cursos de Biomedicina, Design, Pedagogia o ingresso de alunos é, em maior parte, formada por mulheres. Enquanto que nos cursos de BTI, BCT, Educação Física e  Engenharia de Produção, há uma grande diferença de alunos entre os homens e mulheres, tendo, em maior número, os homens. Agora, no curso de Direito, houve um equilíbrio, tendo pouca diferença na quantidade de alunos e alunas ingressantes.

# %% [markdown]
# ### > QUESTÃO 1 - (PÓS-GRADUAÇÃO)

# %%
# 1 - (PPgEEC):  Programa de Pós-graduação em Engenharia Elétrica e de Computação

fig, ax = plt.subplots(1, 11, figsize = (50, 5))

d2009[d2009.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM ENGENHARIA ELÉTRICA E DE COMPUTAÇÃO"].sexo.value_counts().plot.\
bar(title = 'Ingressantes no PPgEEC em 2009', ax=ax[0], ylim = (0,100))

d2010[d2010.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM ENGENHARIA ELÉTRICA E DE COMPUTAÇÃO"].sexo.value_counts().plot.\
bar(title = 'Ingressantes no PPgEEC em 2010', ax=ax[1], ylim = (0,100))

d2011[d2011.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM ENGENHARIA ELÉTRICA E DE COMPUTAÇÃO"].sexo.value_counts().plot.\
bar(title = 'Ingressantes no PPgEEC em 2011', ax=ax[2], ylim = (0,100))

d2012[d2012.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM ENGENHARIA ELÉTRICA E DE COMPUTAÇÃO"].sexo.value_counts().plot.\
bar(title = 'Ingressantes no PPgEEC em 2012', ax=ax[3], ylim = (0,100))

d2013[d2013.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM ENGENHARIA ELÉTRICA E DE COMPUTAÇÃO"].sexo.value_counts().plot.\
bar(title = 'Ingressantes no PPgEEC em 2013', ax=ax[4], ylim = (0,100))

d2014[d2014.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM ENGENHARIA ELÉTRICA E DE COMPUTAÇÃO"].sexo.value_counts().plot.\
bar(title = 'Ingressantes no PPgEEC em 2014', ax=ax[5], ylim = (0,100))

d2015[d2015.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM ENGENHARIA ELÉTRICA E DE COMPUTAÇÃO"].sexo.value_counts().plot.\
bar(title = 'Ingressantes no PPgEEC em 2015', ax=ax[6], ylim = (0,100))

d2016[d2016.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM ENGENHARIA ELÉTRICA E DE COMPUTAÇÃO"].sexo.value_counts().plot.\
bar(title = 'Ingressantes no PPgEEC em 2016', ax=ax[7], ylim = (0,100))

d2017[d2017.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM ENGENHARIA ELÉTRICA E DE COMPUTAÇÃO"].sexo.value_counts().plot.\
bar(title = 'Ingressantes no PPgEEC em 2017', ax=ax[8], ylim = (0,100))

d2018[d2018.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM ENGENHARIA ELÉTRICA E DE COMPUTAÇÃO"].sexo.value_counts().plot.\
bar(title = 'Ingressantes no PPgEEC em 2018', ax=ax[9], ylim = (0,100))

d2019[d2019.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM ENGENHARIA ELÉTRICA E DE COMPUTAÇÃO"].sexo.value_counts().plot.\
bar(title = 'Ingressantes no PPgEEC em 2019', ax=ax[10], ylim = (0,100))

# %% [markdown]
# O número de mulheres ingressantes no PPgEEC é aproximadamente constante desde 2009, mantendo um padrão.

# %%
# 1 - (PPgSC): Programa de Pós-graduação em Sistemas e Computação

fig, ax = plt.subplots(1, 11, figsize = (50, 5))

d2009[d2009.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM SISTEMAS E COMPUTAÇÃO"].sexo.value_counts().plot.\
bar(title = 'Ingressantes no PPgSC em 2009', ax=ax[0], ylim = (0,100))

d2010[d2010.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM SISTEMAS E COMPUTAÇÃO"].sexo.value_counts().plot.\
bar(title = 'Ingressantes no PPgSC em 2010', ax=ax[1], ylim = (0,100))

d2011[d2011.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM SISTEMAS E COMPUTAÇÃO"].sexo.value_counts().plot.\
bar(title = 'Ingressantes no PPgSC em 2011', ax=ax[2], ylim = (0,100))

d2012[d2012.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM SISTEMAS E COMPUTAÇÃO"].sexo.value_counts().plot.\
bar(title = 'Ingressantes no PPgSC em 2012', ax=ax[3], ylim = (0,100))

d2013[d2013.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM SISTEMAS E COMPUTAÇÃO"].sexo.value_counts().plot.\
bar(title = 'Ingressantes no PPgSC em 2013', ax=ax[4], ylim = (0,100))

d2014[d2014.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM SISTEMAS E COMPUTAÇÃO"].sexo.value_counts().plot.\
bar(title = 'Ingressantes no PPgSC em 2014', ax=ax[5], ylim = (0,100))

d2015[d2015.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM SISTEMAS E COMPUTAÇÃO"].sexo.value_counts().plot.\
bar(title = 'Ingressantes no PPgSC em 2015', ax=ax[6], ylim = (0,100))

d2016[d2016.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM SISTEMAS E COMPUTAÇÃO"].sexo.value_counts().plot.\
bar(title = 'Ingressantes no PPgSC em 2016', ax=ax[7], ylim = (0,100))

d2017[d2017.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM SISTEMAS E COMPUTAÇÃO"].sexo.value_counts().plot.\
bar(title = 'Ingressantes no PPgSC em 2017', ax=ax[8], ylim = (0,100))

d2018[d2018.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM SISTEMAS E COMPUTAÇÃO"].sexo.value_counts().plot.\
bar(title = 'Ingressantes no PPgSC em 2018', ax=ax[9], ylim = (0,100))

d2019[d2019.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM SISTEMAS E COMPUTAÇÃO"].sexo.value_counts().plot.\
bar(title = 'Ingressantes no PPgSC em 2019', ax=ax[10], ylim = (0,100))

# %% [markdown]
# O número de mulheres ingressantes em PPgSC é quase constante e mínima, se comparada à quantidade de homens.

# %%
# 1 - (PPgSW):  Programa de Pós-graduação em Engenharia de Software

fig, ax = plt.subplots(1, 6, figsize = (25, 5))

# Só temos dados do PPgSW a partir de 2014.

d2014[d2014.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM ENGENHARIA DE SOFTWARE"].sexo.value_counts().plot.\
bar(title = 'Ingressantes no PPgSW em 2014', ax=ax[0], ylim = (0,100))

d2015[d2015.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM ENGENHARIA DE SOFTWARE"].sexo.value_counts().plot.\
bar(title = 'Ingressantes no PPgSW em 2015', ax=ax[1], ylim = (0,100))

d2016[d2016.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM ENGENHARIA DE SOFTWARE"].sexo.value_counts().plot.\
bar(title = 'Ingressantes no PPgSW em 2016', ax=ax[2], ylim = (0,100))

d2017[d2017.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM ENGENHARIA DE SOFTWARE"].sexo.value_counts().plot.\
bar(title = 'Ingressantes no PPgSW em 2017', ax=ax[3], ylim = (0,100))

d2018[d2018.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM ENGENHARIA DE SOFTWARE"].sexo.value_counts().plot.\
bar(title = 'Ingressantes no PPgSW em 2018', ax=ax[4], ylim = (0,100))

d2019[d2019.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM ENGENHARIA DE SOFTWARE"].sexo.value_counts().plot.\
bar(title = 'Ingressantes no PPgSW em 2019', ax=ax[5], ylim = (0,100))

# %% [markdown]
# O número de mulheres ingressantes em PPgSW em 2015, 2017 e 2018 é quase nula. Já nos anos 2014, 2016 e 2019, não há mulheres ingressantes.

# %%
# 1 - (PPgITE): Programa de Pós-graduação em Inovação em Tecnologias Educacionais

fig, ax = plt.subplots(1, 3, figsize = (15, 5))

# Só temos dados do PPgITE a partir de 2017.
d2017[d2017.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM INOVAÇÃO EM TECNOLOGIAS EDUCACIONAIS"].sexo.value_counts().plot.\
bar(title = 'Ingressantes no PPgITE em 2017', ax=ax[0], ylim = (0,30))

d2018[d2018.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM INOVAÇÃO EM TECNOLOGIAS EDUCACIONAIS"].sexo.value_counts().plot.\
bar(title = 'Ingressantes no PPgITE em 2018', ax=ax[1], ylim = (0,30))

d2019[d2019.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM INOVAÇÃO EM TECNOLOGIAS EDUCACIONAIS"].sexo.value_counts().plot.\
bar(title = 'Ingressantes no PPgITE em 2019', ax=ax[2], ylim = (0,30))

# %% [markdown]
# O número de mulheres ingressantes no PPgITE vai aumentando ao longo do anos, desde 2017.

# %%
# 1 - (PPgBIOINFO): Programa de Pós-graduação em Bioinformática

fig, ax = plt.subplots(1, 4, figsize = (20, 5))

# Só temos dados do PPgBIOINFO a partir do ano de 2016.
d2016[d2016.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM BIOINFORMÁTICA"].sexo.value_counts().plot.\
bar(title = 'Ingressantes no PPgBIOINFO em 2016', ax=ax[0], ylim = (0,20))

d2017[d2017.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM BIOINFORMÁTICA"].sexo.value_counts().plot.\
bar(title = 'Ingressantes no PPgBIOINFO em 2017', ax=ax[1], ylim = (0,20))

d2018[d2018.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM BIOINFORMÁTICA"].sexo.value_counts().plot.\
bar(title = 'Ingressantes no PPgBIOINFO em 2018', ax=ax[2], ylim = (0,20))

d2019[d2019.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM BIOINFORMÁTICA"].sexo.value_counts().plot.\
bar(title = 'Ingressantes no PPgBIOINFO em 2019', ax=ax[3], ylim = (0,20))

# %% [markdown]
# O número de mulheres ingressantes no PPgBIOINFO é muito baixa em 2017, é baixa em 2016 e 2018 e nula em 2019.

# %% [markdown]
# ### > RESPOSTA (PÓS-GRADUAÇÃO):
# Analisando os gráficos dos cursos de Pós-Graduação em: Engenharia Elétrica e de Computação, Sistemas e Computação, Engenharia de Software, Inovação em Tecnologias Educacionais e Bioinformática, é perceptível que a questão da diferença de gêneros ao longo dos anos é comum, pois em quatro dos cinco cursos de Pós-Graduação,  a quantidade de mulheres ingressantes é pequena, se comparada à de homens, e em alguns anos é nula.

# %% [markdown]
# ### > QUESTÃO 2 - (GRADUAÇÃO)

# %%
# 2- (BTI):

fig, ax = plt.subplots(7, 1, figsize = (10, 35))

# como o curso de BTI iniciou em 2013, utilizaremos os dados a partir de 2013:
d2013[d2013.nome_curso == "TECNOLOGIA DA INFORMAÇÃO"].raca.value_counts().plot\
.barh(title = 'Ingressantes no BTI em 2013', ax=ax[0], xlim = (0, 200))

d2014[d2014.nome_curso == "TECNOLOGIA DA INFORMAÇÃO"].raca.value_counts().plot\
.barh(title = 'Ingressantes no BTI em 2014', ax=ax[1], xlim = (0, 200))

d2015[d2015.nome_curso == "TECNOLOGIA DA INFORMAÇÃO"].raca.value_counts().plot\
.barh(title = 'Ingressantes no BTI em 2015', ax=ax[2], xlim = (0, 200))

d2016[d2016.nome_curso == "TECNOLOGIA DA INFORMAÇÃO"].raca.value_counts().plot\
.barh(title = 'Ingressantes no BTI em 2016', ax=ax[3], xlim = (0, 200))

d2017[d2017.nome_curso == "TECNOLOGIA DA INFORMAÇÃO"].raca.value_counts().plot\
.barh(title = 'Ingressantes no BTI em 2017', ax=ax[4], xlim = (0, 200))

d2018[d2018.nome_curso == "TECNOLOGIA DA INFORMAÇÃO"].raca.value_counts().plot\
.barh(title = 'Ingressantes no BTI em 2018', ax=ax[5], xlim = (0, 200))

d2019[d2019.nome_curso == "TECNOLOGIA DA INFORMAÇÃO"].raca.value_counts().plot\
.barh(title = 'Ingressantes no BTI em 2019', ax=ax[6], xlim = (0, 200))

# %%
# 2 - (BCT):

fig, ax = plt.subplots(11, 1, figsize = (10, 50))

d2009[d2009.nome_curso == "CIÊNCIAS E TECNOLOGIA"].raca.value_counts().plot\
.barh(title = 'Ingressantes em BCT em 2009', ax=ax[0], xlim = (0,800))

d2010[d2010.nome_curso == "CIÊNCIAS E TECNOLOGIA"].raca.value_counts().plot\
.barh(title = 'Ingressantes em BCT em 2010', ax=ax[1], xlim = (0,800))

d2011[d2011.nome_curso == "CIÊNCIAS E TECNOLOGIA"].raca.value_counts().plot\
.barh(title = 'Ingressantes em BCT em 2011', ax=ax[2], xlim = (0,800))

d2012[d2012.nome_curso == "CIÊNCIAS E TECNOLOGIA"].raca.value_counts().plot\
.barh(title = 'Ingressantes em BCT em 2012', ax=ax[3], xlim = (0,800))

d2013[d2013.nome_curso == "CIÊNCIAS E TECNOLOGIA"].raca.value_counts().plot\
.barh(title = 'Ingressantes em BCT em 2013', ax=ax[4], xlim = (0,800))

d2014[d2014.nome_curso == "CIÊNCIAS E TECNOLOGIA"].raca.value_counts().plot\
.barh(title = 'Ingressantes em BCT em 2014', ax=ax[5], xlim = (0,800))

d2015[d2015.nome_curso == "CIÊNCIAS E TECNOLOGIA"].raca.value_counts().plot\
.barh(title = 'Ingressantes em BCT em 2015', ax=ax[6], xlim = (0,800))

d2016[d2016.nome_curso == "CIÊNCIAS E TECNOLOGIA"].raca.value_counts().plot\
.barh(title = 'Ingressantes em BCT em 2016', ax=ax[7], xlim = (0,800))

d2017[d2017.nome_curso == "CIÊNCIAS E TECNOLOGIA"].raca.value_counts().plot\
.barh(title = 'Ingressantes em BCT em 2017', ax=ax[8], xlim = (0,800))

d2018[d2018.nome_curso == "CIÊNCIAS E TECNOLOGIA"].raca.value_counts().plot\
.barh(title = 'Ingressantes em BCT em 2018', ax=ax[9], xlim = (0,800))

d2019[d2019.nome_curso == "CIÊNCIAS E TECNOLOGIA"].raca.value_counts().plot\
.barh(title = 'Ingressantes em BCT em 2019', ax=ax[10], xlim = (0,800))

# %%
# 2 - (BIOMEDICINA):

fig, ax = plt.subplots(11, 1, figsize = (10, 50))

d2009[d2009.nome_curso == "BIOMEDICINA"].raca.value_counts().plot.\
barh(title = 'Ingressantes em Biomedicina em 2009', ax=ax[0], xlim = (0,60))

d2010[d2010.nome_curso == "BIOMEDICINA"].raca.value_counts().plot.\
barh(title = 'Ingressantes em Biomedicina em 2010', ax=ax[1], xlim = (0,60))

d2011[d2011.nome_curso == "BIOMEDICINA"].raca.value_counts().plot.\
barh(title = 'Ingressantes em Biomedicina em 2011', ax=ax[2], xlim = (0,60))

d2012[d2012.nome_curso == "BIOMEDICINA"].raca.value_counts().plot.\
barh(title = 'Ingressantes em Biomedicina em 2012', ax=ax[3], xlim = (0,60))

d2013[d2013.nome_curso == "BIOMEDICINA"].raca.value_counts().plot.\
barh(title = 'Ingressantes em Biomedicina em 2013', ax=ax[4], xlim = (0,60))

d2014[d2014.nome_curso == "BIOMEDICINA"].raca.value_counts().plot.\
barh(title = 'Ingressantes em Biomedicina em 2014', ax=ax[5], xlim = (0,60))

d2015[d2015.nome_curso == "BIOMEDICINA"].raca.value_counts().plot.\
barh(title = 'Ingressantes em Biomedicina em 2015', ax=ax[6], xlim = (0,60))

d2016[d2016.nome_curso == "BIOMEDICINA"].raca.value_counts().plot.\
barh(title = 'Ingressantes em Biomedicina em 2016', ax=ax[7], xlim = (0,60))

d2017[d2017.nome_curso == "BIOMEDICINA"].raca.value_counts().plot.\
barh(title = 'Ingressantes em Biomedicina em 2017', ax=ax[8], xlim = (0,60))

d2018[d2018.nome_curso == "BIOMEDICINA"].raca.value_counts().plot.\
barh(title = 'Ingressantes em Biomedicina em 2018', ax=ax[9], xlim = (0,60))

d2019[d2019.nome_curso == "BIOMEDICINA"].raca.value_counts().plot.\
barh(title = 'Ingressantes em Biomedicina em 2019', ax=ax[10], xlim = (0,60))

# %%
# 2 - (DESIGN): 

fig, ax = plt.subplots(11, 1, figsize = (10, 50))

d2009[d2009.nome_curso == "DESIGN"].raca.value_counts().plot.\
barh(title = 'Ingressantes em Design em 2009', ax=ax[0], xlim = (0,40))

d2010[d2010.nome_curso == "DESIGN"].raca.value_counts().plot.\
barh(title = 'Ingressantes em Design em 2010', ax=ax[1], xlim = (0,40))

d2011[d2011.nome_curso == "DESIGN"].raca.value_counts().plot.\
barh(title = 'Ingressantes em Design em 2011', ax=ax[2], xlim = (0,40))

d2012[d2012.nome_curso == "DESIGN"].raca.value_counts().plot.\
barh(title = 'Ingressantes em Design em 2012', ax=ax[3], xlim = (0,40))

d2013[d2013.nome_curso == "DESIGN"].raca.value_counts().plot.\
barh(title = 'Ingressantes em Design em 2013', ax=ax[4], xlim = (0,40))

d2014[d2014.nome_curso == "DESIGN"].raca.value_counts().plot.\
barh(title = 'Ingressantes em Design em 2014', ax=ax[5], xlim = (0,40))

d2015[d2015.nome_curso == "DESIGN"].raca.value_counts().plot.\
barh(title = 'Ingressantes em Design em 2015', ax=ax[6], xlim = (0,40))

d2016[d2016.nome_curso == "DESIGN"].raca.value_counts().plot.\
barh(title = 'Ingressantes em Design em 2016', ax=ax[7], xlim = (0,40))

d2017[d2017.nome_curso == "DESIGN"].raca.value_counts().plot.\
barh(title = 'Ingressantes em Design em 2017', ax=ax[8], xlim = (0,40))

d2018[d2018.nome_curso == "DESIGN"].raca.value_counts().plot.\
barh(title = 'Ingressantes em Design em 2018', ax=ax[9], xlim = (0,40))

d2019[d2019.nome_curso == "DESIGN"].raca.value_counts().plot.\
barh(title = 'Ingressantes em Design em 2019', ax=ax[10], xlim = (0,40))

# %%
# 2 - (DIREITO): 

fig, ax = plt.subplots(11, 1, figsize = (10, 50))

d2009[d2009.nome_curso == "DIREITO"].raca.value_counts().plot.\
barh(title = 'Ingressantes em Direito em 2009', ax=ax[0], xlim = (0,200))

d2010[d2010.nome_curso == "DIREITO"].raca.value_counts().plot.\
barh(title = 'Ingressantes em Direito em 2010', ax=ax[1], xlim = (0,200))

d2011[d2011.nome_curso == "DIREITO"].raca.value_counts().plot.\
barh(title = 'Ingressantes em Direito em 2011', ax=ax[2], xlim = (0,200))

d2012[d2012.nome_curso == "DIREITO"].raca.value_counts().plot.\
barh(title = 'Ingressantes em Direito em 2012', ax=ax[3], xlim = (0,200))

d2013[d2013.nome_curso == "DIREITO"].raca.value_counts().plot.\
barh(title = 'Ingressantes em Direito em 2013', ax=ax[4], xlim = (0,200))

d2014[d2014.nome_curso == "DIREITO"].raca.value_counts().plot.\
barh(title = 'Ingressantes em Direito em 2014', ax=ax[5], xlim = (0,200))

d2015[d2015.nome_curso == "DIREITO"].raca.value_counts().plot.\
barh(title = 'Ingressantes em Direito em 2015', ax=ax[6], xlim = (0,200))

d2016[d2016.nome_curso == "DIREITO"].raca.value_counts().plot.\
barh(title = 'Ingressantes em Direito em 2016', ax=ax[7], xlim = (0,200))

d2017[d2017.nome_curso == "DIREITO"].raca.value_counts().plot.\
barh(title = 'Ingressantes em Direito em 2017', ax=ax[8], xlim = (0,200))

d2018[d2018.nome_curso == "DIREITO"].raca.value_counts().plot.\
barh(title = 'Ingressantes em Direito em 2018', ax=ax[9], xlim = (0,200))

d2019[d2019.nome_curso == "DIREITO"].raca.value_counts().plot.\
barh(title = 'Ingressantes em Direito em 2019', ax=ax[10], xlim = (0,200))

# %%
# 2 - (EDUCAÇÃO FÍSICA):

fig, ax = plt.subplots(11, 1, figsize = (10, 50))

d2009[d2009.nome_curso == "EDUCAÇÃO FÍSICA"].raca.value_counts().plot\
.barh(title = 'Ingressantes em Educação Física em 2009', ax=ax[0], xlim = (0,450))

d2010[d2010.nome_curso == "EDUCAÇÃO FÍSICA"].raca.value_counts().plot\
.barh(title = 'Ingressantes em Educação Física em 2010', ax=ax[1], xlim = (0,450))

d2011[d2011.nome_curso == "EDUCAÇÃO FÍSICA"].raca.value_counts().plot\
.barh(title = 'Ingressantes em Educação Física em 2011', ax=ax[2], xlim = (0,450))

d2012[d2012.nome_curso == "EDUCAÇÃO FÍSICA"].raca.value_counts().plot\
.barh(title = 'Ingressantes em Educação Física em 2012', ax=ax[3], xlim = (0,450))

d2013[d2013.nome_curso == "EDUCAÇÃO FÍSICA"].raca.value_counts().plot\
.barh(title = 'Ingressantes em Educação Física em 2013', ax=ax[4], xlim = (0,450))

d2014[d2014.nome_curso == "EDUCAÇÃO FÍSICA"].raca.value_counts().plot\
.barh(title = 'Ingressantes em Educação Física em 2014', ax=ax[5], xlim = (0,450))

d2015[d2015.nome_curso == "EDUCAÇÃO FÍSICA"].raca.value_counts().plot\
.barh(title = 'Ingressantes em Educação Física em 2015', ax=ax[6], xlim = (0,450))

d2016[d2016.nome_curso == "EDUCAÇÃO FÍSICA"].raca.value_counts().plot\
.barh(title = 'Ingressantes em Educação Física em 2016', ax=ax[7], xlim = (0,450))

d2017[d2017.nome_curso == "EDUCAÇÃO FÍSICA"].raca.value_counts().plot\
.barh(title = 'Ingressantes em Educação Física em 2017', ax=ax[8], xlim = (0,450))

d2018[d2018.nome_curso == "EDUCAÇÃO FÍSICA"].raca.value_counts().plot\
.barh(title = 'Ingressantes em Educação Física em 2018', ax=ax[9], xlim = (0,450))

d2019[d2019.nome_curso == "EDUCAÇÃO FÍSICA"].raca.value_counts().plot\
.barh(title = 'Ingressantes em Educação Física em 2019', ax=ax[10], xlim = (0,450))

# %%
# 2 - (ENGENHARIA DE PRODUÇÃO): 

fig, ax = plt.subplots(11, 1, figsize = (10, 60))

d2009[d2009.nome_curso == "ENGENHARIA DE PRODUÇÃO"].raca.value_counts().plot\
.barh(title = 'Ingressantes em Engenharia de Produção em 2009', ax=ax[0], xlim = (0,100))

d2010[d2010.nome_curso == "ENGENHARIA DE PRODUÇÃO"].raca.value_counts().plot\
.barh(title = 'Ingressantes em Engenharia de Produção em 2010', ax=ax[1], xlim = (0,100))

d2011[d2011.nome_curso == "ENGENHARIA DE PRODUÇÃO"].raca.value_counts().plot\
.barh(title = 'Ingressantes em Engenharia de Produção em 2011', ax=ax[2], xlim = (0,100))

d2012[d2012.nome_curso == "ENGENHARIA DE PRODUÇÃO"].raca.value_counts().plot\
.barh(title = 'Ingressantes em Engenharia de Produção em 2012', ax=ax[3], xlim = (0,100))

d2013[d2013.nome_curso == "ENGENHARIA DE PRODUÇÃO"].raca.value_counts().plot\
.barh(title = 'Ingressantes em Engenharia de Produção em 2013', ax=ax[4], xlim = (0,100))

d2014[d2014.nome_curso == "ENGENHARIA DE PRODUÇÃO"].raca.value_counts().plot\
.barh(title = 'Ingressantes em Engenharia de Produção em 2014', ax=ax[5], xlim = (0,100))

d2015[d2015.nome_curso == "ENGENHARIA DE PRODUÇÃO"].raca.value_counts().plot\
.barh(title = 'Ingressantes em Engenharia de Produção em 2015', ax=ax[6], xlim = (0,100))

d2016[d2016.nome_curso == "ENGENHARIA DE PRODUÇÃO"].raca.value_counts().plot\
.barh(title = 'Ingressantes em Engenharia de Produção em 2016', ax=ax[7], xlim = (0,100))

d2017[d2017.nome_curso == "ENGENHARIA DE PRODUÇÃO"].raca.value_counts().plot\
.barh(title = 'Ingressantes em Engenharia de Produção em 2017', ax=ax[8], xlim = (0,100))

d2018[d2018.nome_curso == "ENGENHARIA DE PRODUÇÃO"].raca.value_counts().plot\
.barh(title = 'Ingressantes em Engenharia de Produção em 2018', ax=ax[9], xlim = (0,100))

d2019[d2019.nome_curso == "ENGENHARIA DE PRODUÇÃO"].raca.value_counts().plot\
.barh(title = 'Ingressantes em Engenharia de Produção em 2019', ax=ax[10], xlim = (0,100))

# %%
# 2 - (PEDAGOGIA): 

fig, ax = plt.subplots(11, 1, figsize = (10, 54))

d2009[d2009.nome_curso == "PEDAGOGIA"].raca.value_counts().plot\
.barh(title = 'Ingressantes em Pedagogia em 2009', ax=ax[0], xlim = (0,350))

d2010[d2010.nome_curso == "PEDAGOGIA"].raca.value_counts().plot\
.barh(title = 'Ingressantes em Pedagogia em 2010', ax=ax[1], xlim = (0,350))

d2011[d2011.nome_curso == "PEDAGOGIA"].raca.value_counts().plot\
.barh(title = 'Ingressantes em Pedagogia em 2011', ax=ax[2], xlim = (0,350))

d2012[d2012.nome_curso == "PEDAGOGIA"].raca.value_counts().plot\
.barh(title = 'Ingressantes em Pedagogia em 2012', ax=ax[3], xlim = (0,350))

d2013[d2013.nome_curso == "PEDAGOGIA"].raca.value_counts().plot\
.barh(title = 'Ingressantes em Pedagogia em 2013', ax=ax[4], xlim = (0,350))

d2014[d2014.nome_curso == "PEDAGOGIA"].raca.value_counts().plot\
.barh(title = 'Ingressantes em Pedagogia em 2014', ax=ax[5], xlim = (0,350))

d2015[d2015.nome_curso == "PEDAGOGIA"].raca.value_counts().plot\
.barh(title = 'Ingressantes em Pedagogia em 2015', ax=ax[6], xlim = (0,350))

d2016[d2016.nome_curso == "PEDAGOGIA"].raca.value_counts().plot\
.barh(title = 'Ingressantes em Pedagogia em 2016', ax=ax[7], xlim = (0,350))

d2017[d2017.nome_curso == "PEDAGOGIA"].raca.value_counts().plot\
.barh(title = 'Ingressantes em Pedagogia em 2017', ax=ax[8], xlim = (0,350))

d2018[d2018.nome_curso == "PEDAGOGIA"].raca.value_counts().plot\
.barh(title = 'Ingressantes em Pedagogia em 2018', ax=ax[9], xlim = (0,350))

d2019[d2019.nome_curso == "PEDAGOGIA"].raca.value_counts().plot\
.barh(title = 'Ingressantes em Pedagogia em 2019', ax=ax[10], xlim = (0,350))

# %%
# 2 - (QUÍMICA): 

fig, ax = plt.subplots(11, 1, figsize = (10, 50))

d2009[d2009.nome_curso == "QUÍMICA"].raca.value_counts().plot\
.barh(title = 'Ingressantes em Química em 2009', ax=ax[0], xlim = (0,200))

d2010[d2010.nome_curso == "QUÍMICA"].raca.value_counts().plot\
.barh(title = 'Ingressantes em Química em 2010', ax=ax[1], xlim = (0,200))

d2011[d2011.nome_curso == "QUÍMICA"].raca.value_counts().plot\
.barh(title = 'Ingressantes em Química em 2011', ax=ax[2], xlim = (0,200))

d2012[d2012.nome_curso == "QUÍMICA"].raca.value_counts().plot\
.barh(title = 'Ingressantes em Química em 2012', ax=ax[3], xlim = (0,200))

d2013[d2013.nome_curso == "QUÍMICA"].raca.value_counts().plot\
.barh(title = 'Ingressantes em Química em 2013', ax=ax[4], xlim = (0,200))

d2014[d2014.nome_curso == "QUÍMICA"].raca.value_counts().plot\
.barh(title = 'Ingressantes em Química em 2014', ax=ax[5], xlim = (0,200))

d2015[d2015.nome_curso == "QUÍMICA"].raca.value_counts().plot\
.barh(title = 'Ingressantes em Química em 2015', ax=ax[6], xlim = (0,200))

d2016[d2016.nome_curso == "QUÍMICA"].raca.value_counts().plot\
.barh(title = 'Ingressantes em Química em 2016', ax=ax[7], xlim = (0,200))

d2017[d2017.nome_curso == "QUÍMICA"].raca.value_counts().plot\
.barh(title = 'Ingressantes em Química em 2017', ax=ax[8], xlim = (0,200))

d2018[d2018.nome_curso == "QUÍMICA"].raca.value_counts().plot\
.barh(title = 'Ingressantes em Química em 2018', ax=ax[9], xlim = (0,200))

d2019[d2019.nome_curso == "QUÍMICA"].raca.value_counts().plot\
.barh(title = 'Ingressantes em Química em 2019', ax=ax[10], xlim = (0,200))

# %% [markdown]
# ### > RESPOSTA (GRADUAÇÃO):
#
# Analisando os gráficos dos cursos de Bacharelado em Tecnologia da Informação (BTI), Bacharelado em Ciências e Tecnologia (BCT), Biomedicina, Design, Direito, Educação Física, Engenharia de Produção, Pedagogia e Química, em relação à etnia ao longo dos anos, é notável que os alunos de etnia amarela, indígena e remanescentes de quilombo são poucos e em números aproximadamente constantes, quase nulos. Com relação aos de etnia negra, houve um aumento, pouco, mas ainda assim, um avanço. Enquanto isso, os de etnia branca e parda são em maior quantidade, além dos que decidiram não informar sua etnia.

# %% [markdown]
# ### > QUESTÃO 2 - (PÓS GRADUAÇÃO)

# %%
# 2 - (PPgEEC):  Programa de Pós-graduação em Engenharia Elétrica e de Computação

fig, ax = plt.subplots(11, 1, figsize = (10, 50))

d2009[d2009.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM ENGENHARIA ELÉTRICA E DE COMPUTAÇÃO"].raca.value_counts().plot.\
barh(title = 'Ingressantes no PPgEEC em 2009', ax=ax[0], xlim = (0,80))

d2010[d2010.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM ENGENHARIA ELÉTRICA E DE COMPUTAÇÃO"].raca.value_counts().plot.\
barh(title = 'Ingressantes no PPgEEC em 2010', ax=ax[1], xlim = (0,80))

d2011[d2011.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM ENGENHARIA ELÉTRICA E DE COMPUTAÇÃO"].raca.value_counts().plot.\
barh(title = 'Ingressantes no PPgEEC em 2011', ax=ax[2], xlim = (0,80))

d2012[d2012.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM ENGENHARIA ELÉTRICA E DE COMPUTAÇÃO"].raca.value_counts().plot.\
barh(title = 'Ingressantes no PPgEEC em 2012', ax=ax[3], xlim = (0,80))

d2013[d2013.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM ENGENHARIA ELÉTRICA E DE COMPUTAÇÃO"].raca.value_counts().plot.\
barh(title = 'Ingressantes no PPgEEC em 2013', ax=ax[4], xlim = (0,80))

d2014[d2014.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM ENGENHARIA ELÉTRICA E DE COMPUTAÇÃO"].raca.value_counts().plot.\
barh(title = 'Ingressantes no PPgEEC em 2014', ax=ax[5], xlim = (0,80))

d2015[d2015.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM ENGENHARIA ELÉTRICA E DE COMPUTAÇÃO"].raca.value_counts().plot.\
barh(title = 'Ingressantes no PPgEEC em 2015', ax=ax[6], xlim = (0,80))

d2016[d2016.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM ENGENHARIA ELÉTRICA E DE COMPUTAÇÃO"].raca.value_counts().plot.\
barh(title = 'Ingressantes no PPgEEC em 2016', ax=ax[7], xlim = (0,80))

d2017[d2017.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM ENGENHARIA ELÉTRICA E DE COMPUTAÇÃO"].raca.value_counts().plot.\
barh(title = 'Ingressantes no PPgEEC em 2017', ax=ax[8], xlim = (0,80))

d2018[d2018.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM ENGENHARIA ELÉTRICA E DE COMPUTAÇÃO"].raca.value_counts().plot.\
barh(title = 'Ingressantes no PPgEEC em 2018', ax=ax[9], xlim = (0,80))

d2019[d2019.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM ENGENHARIA ELÉTRICA E DE COMPUTAÇÃO"].raca.value_counts().plot.\
barh(title = 'Ingressantes no PPgEEC em 2019', ax=ax[10], xlim = (0,80))

# %%
# 2 - (PPgSC): Programa de Pós-graduação em Sistemas e Computação

fig, ax = plt.subplots(11, 1, figsize = (10, 50))

d2009[d2009.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM SISTEMAS E COMPUTAÇÃO"].raca.value_counts().plot.\
barh(title = 'Ingressantes no PPgSC em 2009', ax=ax[0], xlim = (0,50))

d2010[d2010.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM SISTEMAS E COMPUTAÇÃO"].raca.value_counts().plot.\
barh(title = 'Ingressantes no PPgSC em 2010', ax=ax[1], xlim = (0,50))

d2011[d2011.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM SISTEMAS E COMPUTAÇÃO"].raca.value_counts().plot.\
barh(title = 'Ingressantes no PPgSC em 2011', ax=ax[2], xlim = (0,50))

d2012[d2012.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM SISTEMAS E COMPUTAÇÃO"].raca.value_counts().plot.\
barh(title = 'Ingressantes no PPgSC em 2012', ax=ax[3], xlim = (0,50))

d2013[d2013.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM SISTEMAS E COMPUTAÇÃO"].raca.value_counts().plot.\
barh(title = 'Ingressantes no PPgSC em 2013', ax=ax[4], xlim = (0,50))

d2014[d2014.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM SISTEMAS E COMPUTAÇÃO"].raca.value_counts().plot.\
barh(title = 'Ingressantes no PPgSC em 2014', ax=ax[5], xlim = (0,50))

d2015[d2015.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM SISTEMAS E COMPUTAÇÃO"].raca.value_counts().plot.\
barh(title = 'Ingressantes no PPgSC em 2015', ax=ax[6], xlim = (0,50))

d2016[d2016.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM SISTEMAS E COMPUTAÇÃO"].raca.value_counts().plot.\
barh(title = 'Ingressantes no PPgSC em 2016', ax=ax[7], xlim = (0,50))

d2017[d2017.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM SISTEMAS E COMPUTAÇÃO"].raca.value_counts().plot.\
barh(title = 'Ingressantes no PPgSC em 2017', ax=ax[8], xlim = (0,50))

d2018[d2018.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM SISTEMAS E COMPUTAÇÃO"].raca.value_counts().plot.\
barh(title = 'Ingressantes no PPgSC em 2018', ax=ax[9], xlim = (0,50))

d2019[d2019.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM SISTEMAS E COMPUTAÇÃO"].raca.value_counts().plot.\
barh(title = 'Ingressantes no PPgSC em 2019', ax=ax[10], xlim = (0,50))

# %%
# 2 - (PPgSW):  Programa de Pós-graduação em Engenharia de Software

fig, ax = plt.subplots(6, 1, figsize = (10, 25))

d2014[d2014.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM ENGENHARIA DE SOFTWARE"].raca.value_counts().plot.\
barh(title = 'Ingressantes no PPgSW em 2014', ax=ax[0], xlim = (0,15))

d2015[d2015.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM ENGENHARIA DE SOFTWARE"].raca.value_counts().plot.\
barh(title = 'Ingressantes no PPgSW em 2015', ax=ax[1], xlim = (0,15))

d2016[d2016.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM ENGENHARIA DE SOFTWARE"].raca.value_counts().plot.\
barh(title = 'Ingressantes no PPgSW em 2016', ax=ax[2], xlim = (0,15))

d2017[d2017.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM ENGENHARIA DE SOFTWARE"].raca.value_counts().plot.\
barh(title = 'Ingressantes no PPgSW em 2017', ax=ax[3], xlim = (0,15))

d2018[d2018.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM ENGENHARIA DE SOFTWARE"].raca.value_counts().plot.\
barh(title = 'Ingressantes no PPgSW em 2018', ax=ax[4], xlim = (0,15))

d2019[d2019.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM ENGENHARIA DE SOFTWARE"].raca.value_counts().plot.\
barh(title = 'Ingressantes no PPgSW em 2019', ax=ax[5], xlim = (0,15))

# %%
# 2 - (PPgITE): Programa de Pós-graduação em Inovação em Tecnologias Educacionais

fig, ax = plt.subplots(3, 1, figsize = (10, 15))

d2017[d2017.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM INOVAÇÃO EM TECNOLOGIAS EDUCACIONAIS"].raca.value_counts().plot.\
barh(title = 'Ingressantes no PPgITE em 2017', ax=ax[0], xlim = (0,30))

d2018[d2018.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM INOVAÇÃO EM TECNOLOGIAS EDUCACIONAIS"].raca.value_counts().plot.\
barh(title = 'Ingressantes no PPgITE em 2018', ax=ax[1], xlim = (0,30))

d2019[d2019.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM INOVAÇÃO EM TECNOLOGIAS EDUCACIONAIS"].raca.value_counts().plot.\
barh(title = 'Ingressantes no PPgITE em 2019', ax=ax[2], xlim = (0,30))

# %%
# 2 - (PPgBIOINFO): Programa de Pós-graduação em Bioinformática

fig, ax = plt.subplots(4, 1, figsize = (10, 20))

d2016[d2016.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM BIOINFORMÁTICA"].raca.value_counts().plot.\
barh(title = 'Ingressantes no PPgBIOINFO em 2016', ax=ax[0], xlim = (0,20))

d2017[d2017.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM BIOINFORMÁTICA"].raca.value_counts().plot.\
barh(title = 'Ingressantes no PPgBIOINFO em 2017', ax=ax[1], xlim = (0,20))

d2018[d2018.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM BIOINFORMÁTICA"].raca.value_counts().plot.\
barh(title = 'Ingressantes no PPgBIOINFO em 2018', ax=ax[2], xlim = (0,20))

d2019[d2019.nome_unidade == "PROGRAMA DE PÓS-GRADUAÇÃO EM BIOINFORMÁTICA"].raca.value_counts().plot.\
barh(title = 'Ingressantes no PPgBIOINFO em 2019', ax=ax[3], xlim = (0,20))

# %% [markdown]
# ### > RESPOSTA (PÓS-GRADUAÇÃO):
#
# Analisando os gráficos dos cursos de Pós-Graduação em: Engenharia Elétrica e de Computação, Sistemas e Computação, Engenharia de Software, Inovação em Tecnologias Educacionais e Bioinformática, em relação à etnia ao longo dos anos, é notável que os alunos de etnia negra, amarela e indígena são poucos e em números aproximadamente constantes, enquanto os de etnia branca e parda são em maior quantidade,  além dos que decidiram não informar sua etnia.
